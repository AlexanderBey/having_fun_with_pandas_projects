# %%
# Library: pandas, numpy, matplotlib, seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# list files in a current directory
c = os.getcwd()
os.listdir(c)
# Out:
# ['data-analysis.ipynb', 'data-set']

# %%
# Importing the dataset
exchange_rates = pd.read_csv('./data-set/data.csv')

# Renaming columns
rename = exchange_rates.rename(columns={'[US dollar ]':'US_dollar',
                                        'Period\\Unit:':'Time'},
                               inplace=True)

# Converting Time column to datetime
convert_time = exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])

# Sorting values by Time in ascending order
sorting_time = exchange_rates.sort_values('Time', inplace=True)

# We reset the index and drop the initial index
reset_index = exchange_rates.reset_index(drop=True, inplace=True) 

# Isolate the columns Time and US_dollar
euro_to_dollar = exchange_rates[['Time', 'US_dollar']]


# Control flow
rename
convert_time
sorting_time
reset_index


# Drop the rows where the - symbol appears
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']

# Convert the US_dollar column to a float data type
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

# Showing the results
exchange_rates

euro_to_dollar
# Out:
#            Time  US_dollar
# 0    1999-01-04     1.1789
# 1    1999-01-05     1.1790
# 2    1999-01-06     1.1743
# 3    1999-01-07     1.1632
# 4    1999-01-08     1.1659
# ...         ...        ...
# 6306 2023-05-22     1.0822
# 6307 2023-05-23     1.0779
# 6308 2023-05-24     1.0785
# 6309 2023-05-25     1.0735
# 6310 2023-05-26     1.0751
#
# [6249 rows x 2 columns]

# %%
# Plotting the line graph

import matplotlib.pyplot as plt
# %matplotlib inline 
# Enables Jupyter to display graphs

plt.plot(euro_to_dollar['Time'], 
         euro_to_dollar['US_dollar'])
plt.show()

# %%
# Rolling mean 
values = pd.DataFrame()
values['daily_values'] = pd.Series(range(1,20,2))

# rolling mean takes the mean of the current and the previous value
# the argument is the number of previous values to take into account
values['rolling_mean_2'] = values['daily_values'].rolling(2).mean()
values['rolling_mean_3'] = values['daily_values'].rolling(3).mean()
values['roling_mean_4'] = values['daily_values'].rolling(4).mean()
values['rolling_mean_4'] = values['daily_values'].rolling(5).mean()
values
# Out:
#    daily_values  rolling_mean_2  rolling_mean_3  roling_mean_4  rolling_mean_4
# 0             1             NaN             NaN            NaN             NaN
# 1             3             2.0             NaN            NaN             NaN
# 2             5             4.0             3.0            NaN             NaN
# 3             7             6.0             5.0            4.0             NaN
# 4             9             8.0             7.0            6.0             5.0
# 5            11            10.0             9.0            8.0             7.0
# 6            13            12.0            11.0           10.0             9.0
# 7            15            14.0            13.0           12.0            11.0
# 8            17            16.0            15.0           14.0            13.0
# 9            19            18.0            17.0           16.0            15.0
